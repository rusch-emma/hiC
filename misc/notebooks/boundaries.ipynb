# %%
import glob
import itertools
import multiprocessing as mp
import os

import bioframe
import cooler
import cooltools.insulation
import cooltools.lib.plotting
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from skimage.filters import threshold_li, threshold_otsu

# %%
windows = [10000]
resolution = 1000

cooler_dir = '/groups/goloborodko/projects/lab/baxterLab2020/results/distiller/coolers_library'
coolers = [f for f in glob.glob(os.path.join(cooler_dir, '*.mapq_30.1000.mcool'))]

out_path = '/groups/goloborodko/projects/lab/baxterLab2020/results/boundaries/boundaries.csv'

boundaries_result = pd.DataFrame(columns=windows)

# %%
def calc_boundaries(cooler_path, windows):
    #print(f'calc_boundaries: {clr}')
    clr = cooler.Cooler('::/resolutions/'.join((cooler_path, str(resolution))))

    boundaries = cooltools.insulation.find_boundaries(
            cooltools.insulation.calculate_insulation_score(clr, windows)
        )

    out = []
    for window in windows:
        threshold = threshold_otsu(
            boundaries[f'boundary_strength_{window}'].dropna().values
        )
        out.append((boundaries[f'boundary_strength_{window}'].dropna() >= threshold).sum())

    return (os.path.basename(cooler_path).split('_nextseq')[0], out)

# %%
def store_boundaries(result):
    boundaries_result.loc[result[0]] = result[1]

# %%
def error_f(err):
    print(err)

# %%
pool = mp.Pool(mp.cpu_count())

for cooler_path in coolers:
    pool.apply_async(calc_boundaries, args=(cooler_path, windows), callback=store_boundaries, error_callback=error_f)

pool.close()
pool.join()

# %%
boundaries_result
# Out:
#                                                    10000
# 200828_HiC_2083_cdc45td_noco_2b                      322
# 200129_HiC_1424_cdc20td_ipl1321_brn1v5_cdc20_1b      287
# 200819_HiC_2144_cdc15td_cdc15_2b                     294
# 201120_HiC_500_smc2tdsmc2K38I_45sphase_1b            245
# 210118_HiC_2122_top2tdsmc2tdsmc2K381_45sphase_1b     231
# 201120_HiC_2432_cdc20tdcdc45td_cdc20_1b              272
# 190617_HiC_ak265_cdc45td_top2td_noco_1b              310
# 200302_HiC_222_cdc20td_cdc510_brn1v5_cdc20_1b        262
# 201120_HiC_1807_cdc20tdtop2tdrad51del_cdc20_1b       295
# 190723_HiC_938_cdc20td_noco_1b                       260
# 201217_HiC_1811_cdc20tdtop2tdtop2yf_cdc20_nocod...   354
# 210118_HiC_2542_cdc20tdtop2tdbm160_cdc20_2b          249
# 200828_HiC_574_cdc20tdtop2tdscc173_cdc20_1b          284
# 200819_HiC_2146_cdc15tdtop2td_cdc15_2b               283
# 201217_HiC_1811_cdc20tdtop2tdtop2yf_cdc20_1b         297
# 190425_HiC_1009_cdc20td_smc2td_cdc20_2b              263
# 200828_HiC_2200_cdc45tdsmc2tdtop2td_noco_1b          322
# 190617_HiC_1785_cdc45td_smc2td_noco_1b               316
# 210118_HiC_1992_top2td_45sphase_1b                   252
# 190305_HiC_939_cdc20td_top2td_cdc20_1b               261
# 200819_HiC_938_cdc20td_cdc20_nocodeplete_1b          323
# 200828_HiC_949_cdc20tdscc173_noco_2b                 290
# 200302_HiC_938_cdc20td_noco_2b                       280
# 190524_HiC_939_cdc20td_top2td_cdc20_2b               250
# 190425_HiC_1699_cdc20td_smc2td_top2td_cdc20_1b       211
# 201104_HiC_2444_cdc20tdsmc2tdscc173_cdc20_1b         290
# 201104_HiC_2444_cdc20tdsmc2tdscc173_noco_1b          289
# 201104_HiC_2085_cdc45tdtop2td_noco_2b                308
# 190723_HiC_ak324_cdc15td_cdc15_1b                    305
# 200302_HiC_1787_cdc45td_scc173_noco_1b               326
# 200302_HiC_858_cdc20td_brn1v5_cdc20_1b               272
# 190425_HiC_938_cdc20td_cdc20_1b                      287
# 210118_HiC_2615_cdc20tdtop2tdscc173bm160_cdc20_1b    286
# 190903_HiC_939_cdc20td_top2td_noco_1b                289
# 190524_HiC_1699_cdc20td_smc2td_top2td_cdc20_2b       220
# 200819_HiC_939_cdc20tdtop2td_cdc20_nocodeplete_1b    290
# 210118_HiC_2585_cdc20tdbm160_cdc20_1b                256
# 200819_HiC_2268_cdc15tdtop2tdsmc2td_cdc15_1b         258
# 190617_HiC_1633_cdc45td_top2td_scc1_noco_1b          329
# 190305_HiC_1009_cdc20td_smc2td_cdc20_1b              253
# 201120_HiC_1991_dgb_45sphase_1b                      255
# 190617_HiC_1787_cdc45td_scc1_noco_1b                 327
# 191021_HiC_938_cdc20td_G1_1b                         298
# 200116_HiC_949_cdc20td_scc1_noco_1b                  282
# 200309_HiC_939_cdc20td_top2td_noco_2b                296
# 201104_HiC_938_cdc20td_G1_2b                         297
# 190903_HiC_939_cdc20td_top2td_cdc20_3b               249
# 190425_HiC_ak263_cdc45td_noco_1b                     335
# 200907_HiC_574_cdc20tdtop2tdscc173_noco_1b           291
# 190425_HiC_949_cdc20td_scc1_1b                       303
# 200116_HiC_1009_cdc20td_smc2td_noco_1b               267
# 190723_HiC_938_cdc20td_cdc20_2b                      262
# 190723_HiC_ak326_cdc15td_top2td_cdc15_1b             303
# 191021_HiC_939_cdc20td_top2td_G1_1b                  299

# %% [markdown]
# boundaries_result.to_csv(out_path)
